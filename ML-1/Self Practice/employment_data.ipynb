# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Messy_Employment_India_Dataset.csv')

# %% [markdown]
# # 3. EDA

# %% [markdown]
# #### 3.1 Viewing Data

# %%
df.shape
# Out:
# (2000, 9)

# %%
df.head()
# Out:
#        Status Age Group    Education    Industry   Location   AI Risk  \
# 0    EMPLOYED     25_34  high school  Technology      Urban       NaN
# 1    EMPLOYED     18-24      Diploma     Fintech      rural  moderate
# 2    EMPLOYED     25_34  High School      Retail      Delhi       Low
# 3  UNEMPLOYED     18-24      Masters      Retail      Urban       Low
# 4         NaN     45-54      Diploma     Fintech  Hyderabad       low
#
#    Years of Experience  Monthly Salary (INR) Date Recorded
# 0                  NaN               40700.0      1/1/2023
# 1                  NaN               17500.0      1/2/2023
# 2                 16.0               77600.0      1/3/2023
# 3                 30.0              100200.0      1/4/2023
# 4                  9.0               19500.0      1/5/2023

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Status                1732 non-null   object
#  1   Age Group             1768 non-null   object
#  2   Education             1804 non-null   object
#  3   Industry              1799 non-null   object
#  4   Location              1787 non-null   object
#  5   AI Risk               1716 non-null   object
#  6   Years of Experience   980 non-null    float64
#  7   Monthly Salary (INR)  1613 non-null   float64
#  8   Date Recorded         2000 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 140.8+ KB

# %% [markdown]
# #### 3.2 Summary Stats

# %%
df.describe()
# Out:
#        Years of Experience  Monthly Salary (INR)
# count           980.000000           1613.000000
# mean             15.244898          76886.360818
# std               9.103941          41628.008054
# min               0.000000           5100.000000
# 25%               7.000000          40700.000000
# 50%              16.000000          77200.000000
# 75%              23.000000         112400.000000
# max              30.000000         149900.000000

# %% [markdown]
# #### 3.3 Value count analysis

# %%
for col in df.columns:
    if col == 'Monthly Salary (INR)':
        continue
    print((f"{'-'*30} {col} {'-'*30}").center(70))
    print("No. Of Unique Values :",df[col].nunique())
    print("Values-> \n",df[col].unique())
    print("-"*70)
# Out:
#  ------------------------------ Status ------------------------------
# No. Of Unique Values : 6
# Values->
#  ['EMPLOYED' 'UNEMPLOYED' nan 'Unemployed' 'employed' 'unemployed'
#  'Employed']
# ----------------------------------------------------------------------
# ------------------------------ Age Group ------------------------------
# No. Of Unique Values : 7
# Values->
#  ['25_34' '18-24' '45-54' '35 - 44' '55+' '25-34' '18 to 24' nan]
# ----------------------------------------------------------------------
# ------------------------------ Education ------------------------------
# No. Of Unique Values : 9
# Values->
#  ['high school' 'Diploma' 'High School' 'Masters' 'PhD' 'Master' 'Ph.D'
#  'Bachelors' nan "Bachelor's"]
# ----------------------------------------------------------------------
# ------------------------------ Industry ------------------------------
# No. Of Unique Values : 8
# Values->
#  ['Technology' ' Fintech' 'Retail' 'Tech ' nan 'Health' 'Healthcare'
#  'Education' 'Finance']
# ----------------------------------------------------------------------
# ------------------------------ Location ------------------------------
# No. Of Unique Values : 8
# Values->
#  ['Urban' 'rural' 'Delhi' 'Hyderabad' 'Bangalore' 'Mumbai' nan 'urban'
#  'suburban']
# ----------------------------------------------------------------------
# ------------------------------ AI Risk ------------------------------
# No. Of Unique Values : 6
# Values->
#  [nan 'moderate' 'Low' 'low' 'HIGH' 'Medium' 'High']
# ----------------------------------------------------------------------
# ------------------------------ Years of Experience ------------------------------
# No. Of Unique Values : 31
# Values->
#  [nan 16. 30.  9. 20. 28.  0.  3. 18.  6.  5. 24. 12. 22. 15.  2.  8. 25.
#  10.  1. 11.  4. 17.  7. 27. 26. 21. 23. 19. 29. 14. 13.]
# ----------------------------------------------------------------------
# ------------------------------ Date Recorded ------------------------------
# No. Of Unique Values : 2000
# Values->
#  ['1/1/2023' '1/2/2023' '1/3/2023' ... '6/20/2028' '6/21/2028' '6/22/2028']
# ----------------------------------------------------------------------

# %% [markdown]
# #### 4.4 Handling inconsistant categories

# %%
# 1. Status 
df['Status'] = (
    df['Status']
    .astype(str)
    .str.strip()
    .str.lower()
    .map({'employed': 1, 'unemployed': 0})
)

df = df.rename(columns={'Status': 'is_employed'})

# %%
# 2. Age Group
df['Age Group'] = df['Age Group'].replace(
    {
        '18-24':"Entry-Level",
        '18 to 24':"Entry-Level",
        '25_34':"Early Career",
        '25-34':"Early Career",
        '35 - 44':  "Mid-Career Professional",
        '45-54':"Senior Professional",
         '55+': "Pre-Retirement"
    }
)

# %%
# 3 Education
df['Education'].astype(str).str.strip().str.lower().unique()
# Out:
# array(['high school', 'diploma', 'masters', 'phd', 'master', 'ph.d',
#        'bachelors', 'nan', "bachelor's"], dtype=object)

# %%
df['Education'] = (
    df['Education'].astype(str).str.strip().str.lower()
    .map({
        'high school':"high school",
        'master':'masters',
        'ph.d':'phd',
        "bachelor's":'bachelors'
    })
)

# %%
# 4. Industry
df['Industry'].astype(str).str.strip().str.lower().unique()
# Out:
# array(['technology', 'fintech', 'retail', 'tech', 'nan', 'health',
#        'healthcare', 'education', 'finance'], dtype=object)

# %%
df['Industry'] = (
    df['Industry']
    .astype(str)
    .str.strip()
    .str.lower()
    .replace({
        'tech': 'technology',
        'health': 'healthcare'
    })
)

# %%
# 5. Location 
know_cities = ['delhi', 'hyderabad', 'bangalore' ,'mumbai']
df['Location'] = df['Location'].str.strip().str.lower()
df['Location'].unique()
# Out:
# array(['urban', 'rural', 'delhi', 'hyderabad', 'bangalore', 'mumbai', nan,
#        'suburban'], dtype=object)

# %%
import numpy as np

# %%
# --- LOGIC FOR COLUMN 1: CITY ---
df['Cities'] = df['Location'].apply(lambda x : x if x in know_cities else np.nan)
# --- LOGIC FOR COLUMN 2: AREA_TYPE ---
def fix_location(value):
    if pd.isna(value):
        return np.nan
    # 1
    if value in know_cities:
        return 'urban'
    if value in ['urban', 'rural','suburban'] :
        return value 

    return 'check!'

# %%
df['Location'].unique()
# Out:
# array(['urban', 'rural', 'delhi', 'hyderabad', 'bangalore', 'mumbai', nan,
#        'suburban'], dtype=object)

# %%
df['Area_Type'] = df['Location'].apply(fix_location)

# %%
df['Area_Type'].unique()
# Out:
# array(['urban', 'rural', nan, 'suburban'], dtype=object)

# %%
# 6. AI Risk
df['AI Risk'].str.strip().str.lower().unique()
# Out:
# array([nan, 'moderate', 'low', 'high', 'medium'], dtype=object)

# %%
df['AI Risk'] = (
    df['AI Risk'].str.strip().str.lower()
    .replace({'medium':'moderate'})
)

# %%
for col in df.columns:
    if col == 'Monthly Salary (INR)':
        continue
    print((f"{'-'*30} {col} {'-'*30}").center(70))
    print("No. Of Unique Values :",df[col].nunique())
    print("Values-> \n",df[col].unique())
    print("-"*70)
# Out:
# ------------------------------ is_employed ------------------------------
# No. Of Unique Values : 2
# Values->
#  [ 1.  0. nan]
# ----------------------------------------------------------------------
# ------------------------------ Age Group ------------------------------
# No. Of Unique Values : 5
# Values->
#  ['Early Career' 'Entry-Level' 'Senior Professional'
#  'Mid-Career Professional' 'Pre-Retirement' nan]
# ----------------------------------------------------------------------
# ------------------------------ Education ------------------------------
# No. Of Unique Values : 4
# Values->
#  ['high school' nan 'masters' 'phd' 'bachelors']
# ----------------------------------------------------------------------
# ------------------------------ Industry ------------------------------
# No. Of Unique Values : 7
# Values->
#  ['technology' 'fintech' 'retail' 'nan' 'healthcare' 'education' 'finance']
# ----------------------------------------------------------------------
# ------------------------------ Location ------------------------------
# No. Of Unique Values : 7
# Values->
#  ['urban' 'rural' 'delhi' 'hyderabad' 'bangalore' 'mumbai' nan 'suburban']
# ----------------------------------------------------------------------
# ------------------------------ AI Risk ------------------------------
# No. Of Unique Values : 3
# Values->
#  [nan 'moderate' 'low' 'high']
# ----------------------------------------------------------------------
# ------------------------------ Years of Experience ------------------------------
# No. Of Unique Values : 31
# Values->
#  [nan 16. 30.  9. 20. 28.  0.  3. 18.  6.  5. 24. 12. 22. 15.  2.  8. 25.
#  10.  1. 11.  4. 17.  7. 27. 26. 21. 23. 19. 29. 14. 13.]
# ----------------------------------------------------------------------
# ------------------------------ Date Recorded ------------------------------
# No. Of Unique Values : 2000
# Values->
#  ['1/1/2023' '1/2/2023' '1/3/2023' ... '6/20/2028' '6/21/2028' '6/22/2028']
# ----------------------------------------------------------------------
#  ------------------------------ Cities ------------------------------
# No. Of Unique Values : 4
# Values->
#  [nan 'delhi' 'hyderabad' 'bangalore' 'mumbai']
# ----------------------------------------------------------------------
# ------------------------------ Area_Type ------------------------------
# No. Of Unique Values : 3
# Values->
#  ['urban' 'rural' nan 'suburban']
# ----------------------------------------------------------------------

# %%
df.head(15)
# Out:
#     is_employed                Age Group    Education    Industry   Location  \
# 0           1.0             Early Career  high school  technology      urban
# 1           1.0              Entry-Level          NaN     fintech      rural
# 2           1.0             Early Career  high school      retail      delhi
# 3           0.0              Entry-Level          NaN      retail      urban
# 4           NaN      Senior Professional          NaN     fintech  hyderabad
# 5           0.0             Early Career          NaN  technology  bangalore
# 6           1.0  Mid-Career Professional      masters         nan     mumbai
# 7           0.0  Mid-Career Professional      masters         nan      rural
# 8           1.0  Mid-Career Professional          phd      retail        NaN
# 9           0.0           Pre-Retirement          phd  technology        NaN
# 10          0.0      Senior Professional      masters         nan  bangalore
# 11          0.0      Senior Professional  high school  technology      delhi
# 12          0.0  Mid-Career Professional  high school      retail      delhi
# 13          1.0              Entry-Level          NaN  technology      rural
# 14          NaN      Senior Professional  high school  healthcare      urban
#
#      AI Risk  Years of Experience  Monthly Salary (INR) Date Recorded  \
# 0        NaN                  NaN               40700.0      1/1/2023
# 1   moderate                  NaN               17500.0      1/2/2023
# 2        low                 16.0               77600.0      1/3/2023
# 3        low                 30.0              100200.0      1/4/2023
# 4        low                  9.0               19500.0      1/5/2023
# 5       high                  NaN               54500.0      1/6/2023
# 6   moderate                 20.0              136500.0      1/7/2023
# 7        low                 28.0               25300.0      1/8/2023
# 8   moderate                  0.0              103600.0      1/9/2023
# 9        NaN                  3.0              126500.0     1/10/2023
# 10      high                  NaN               73400.0     1/11/2023
# 11      high                  NaN               27000.0     1/12/2023
# 12       NaN                  NaN                   NaN     1/13/2023
# 13       low                  NaN              121700.0     1/14/2023
# 14       low                  NaN              132100.0     1/15/2023
#
#        Cities Area_Type
# 0         NaN     urban
# 1         NaN     rural
# 2       delhi     urban
# 3         NaN     urban
# 4   hyderabad     urban
# 5   bangalore     urban
# 6      mumbai     urban
# 7         NaN     rural
# 8         NaN       NaN
# 9         NaN       NaN
# 10  bangalore     urban
# 11      delhi     urban
# 12      delhi     urban
# 13        NaN     rural
# 14        NaN     urban

# %%
((df.isnull().sum()/len(df))*100 ).round(2)
# Out:
# is_employed             13.40
# Age Group               11.60
# Education               52.15
# Industry                 0.00
# Location                10.65
# AI Risk                 14.20
# Years of Experience     51.00
# Monthly Salary (INR)    19.35
# Date Recorded            0.00
# Cities                  54.65
# Area_Type               10.65
# dtype: float64

# %%
df['Industry'].unique()
# Out:
# array(['technology', 'fintech', 'retail', 'nan', 'healthcare',
#        'education', 'finance'], dtype=object)

# %%
df.describe()
# Out:
#        is_employed  Years of Experience  Monthly Salary (INR)
# count  1732.000000           980.000000           1613.000000
# mean      0.510970            15.244898          76886.360818
# std       0.500024             9.103941          41628.008054
# min       0.000000             0.000000           5100.000000
# 25%       0.000000             7.000000          40700.000000
# 50%       1.000000            16.000000          77200.000000
# 75%       1.000000            23.000000         112400.000000
# max       1.000000            30.000000         149900.000000

# %% [markdown]
# ### Fixes acording to me (ash)
# 1. fill with unemployed if salary is 0
# 2. age group -> fill with mode value
# 3. Edu -> skip
# 4. !Null
# 5. Ai Risk -> find ai-risk mode of each job cagetory then will acordingly
# 6. Exp-> skip
# 7. salary -> if is_employed is 0 -> salary = 0
# 8. !Null
# 9. area ->
#     - if 50K salary < 1L = suburban
#     - if > 1L = urban

# %%
df.columns
# Out:
# Index(['is_employed', 'Age Group', 'Education', 'Industry', 'Location',
#        'AI Risk', 'Years of Experience', 'Monthly Salary (INR)',
#        'Date Recorded', 'Cities', 'Area_Type'],
#       dtype='object')

# %%
# Tas
df[(df['is_employed'] == 'No')&(df['Monthly Salary (INR)'].isna())]
# Out:
# Empty DataFrame
# Columns: [is_employed, Age Group, Education, Industry, Location, AI Risk, Years of Experience, Monthly Salary (INR), Date Recorded, Cities, Area_Type]
# Index: []

# %%
# Tas
df[(df['is_employed'] == 'No')&(df['Monthly Salary (INR)'] != 0)]
# Out:
# Empty DataFrame
# Columns: [is_employed, Age Group, Education, Industry, Location, AI Risk, Years of Experience, Monthly Salary (INR), Date Recorded, Cities, Area_Type]
# Index: []

# %%
df[(df['is_employed'] == 'Yes') & (df['Monthly Salary (INR)'] == 0)]
# Out:
# Empty DataFrame
# Columns: [is_employed, Age Group, Education, Industry, Location, AI Risk, Years of Experience, Monthly Salary (INR), Date Recorded, Cities, Area_Type]
# Index: []

# %%
df['Monthly Salary (INR)'].isnull().sum()
# Out:
# np.int64(387)

# %%
# Fixing 'Salary' -> 
df.loc[
    (df['is_employed'] == 'No') & (df['Monthly Salary (INR)'].isna()),
    'Monthly Salary (INR)'
] = 0
